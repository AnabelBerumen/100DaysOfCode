# %% [markdown]
# <a href="https://colab.research.google.com/github/AnabelBerumen/100DaysOfCode/blob/main/Data%20Cleaning/Pandas%20Cookbook/2_Selection_and_Assigment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## intro

# %%
import pandas as pd
import numpy as np

# %%
ser = pd.Series(list('abc') * 3)
ser
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# 4    b
# 5    c
# 6    a
# 7    b
# 8    c
# dtype: object

# %%
ser[[3]]
# Out:
# 3    a
# dtype: object

# %%
ser[[0, 2]]
# Out:
# 0    a
# 2    c
# dtype: object

# %%
ser[:3] # slicing
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
# last for elements
ser[-4:]
# Out:
# 5    c
# 6    a
# 7    b
# 8    c
# dtype: object

# %%
ser[0:8:2] # start stop step
# Out:
# 0    a
# 2    c
# 4    b
# 6    a
# dtype: object

# %%
ser = pd.Series(range(3), index=["Jack", "Jill", "Jayne"])
ser
# Out:
# Jack     0
# Jill     1
# Jayne    2
# dtype: int64

# %%
ser['Jill']
# Out:
# 1

# %%
ser[['Jill']]
# Out:
# Jill    1
# dtype: int64

# %%
ser = pd.Series(list('abc'), index=[2, 42, 21])
ser
# Out:
# 2     a
# 42    b
# 21    c
# dtype: object

# %%
ser[2]
# Out:
# 'a'

# %%
ser[:2]
# Out:
# 2     a
# 42    b
# dtype: object

# %%
ser = pd.Series(["apple", "banana", "orange"], index=[0, 1, 1])
ser
# Out:
# 0     apple
# 1    banana
# 1    orange
# dtype: object

# %%
ser[1]
# Out:
# 1    banana
# 1    orange
# dtype: object

# %% [markdown]
# ## Basic selection from a DataFrame

# %%
df = pd.DataFrame(np.arange(9).reshape(3, -1), columns=['a', 'b', 'c'])
df
# Out:
#    a  b  c
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
df['a'] # return pd.series
# Out:
# 0     0
# 1     4
# 2     8
# 3    12
# Name: a, dtype: int64

# %%
df[['a']] # return pd.DataFrame
# Out:
#     a
# 0   0
# 1   4
# 2   8
# 3  12

# %%
df[['a', 'c']]
# Out:
#     a   c
# 0   0   2
# 1   4   6
# 2   8  10
# 3  12  14

# %%
df[:2] # all col 2 rows
# Out:
#    a  b  c  d
# 0  0  1  2  3
# 1  4  5  6  7

# %%
df[['c', 'a']]
# Out:
#     c   a
# 0   2   0
# 1   6   4
# 2  10   8
# 3  14  12

# %%
ser = pd.Series(["apple", "banana", "orange"], index=[0, 1, 1])
ser
# Out:
# 0     apple
# 1    banana
# 1    orange
# dtype: object

# %%
ser.iloc[2] # scalar
# Out:
# 'orange'

# %%
ser.iloc[[1]] # return pd.Series
# Out:
# 1    banana
# dtype: object

# %%
ser.iloc[[0, 2]]
# Out:
# 0     apple
# 1    orange
# dtype: object

# %%
ser.iloc[:2]
# Out:
# 0     apple
# 1    banana
# dtype: object

# %% [markdown]
# ## Position-based Selection of DataFrame

# %%
df = pd.DataFrame(np.arange(20).reshape(5, -1), columns=list('abcd'))
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
# 4  16  17  18  19

# %%
df.iloc[2,2]
# Out:
# 10

# %%
df.iloc[:, 0]
# Out:
# 0     0
# 1     4
# 2     8
# 3    12
# 4    16
# Name: a, dtype: int64

# %%
df.iloc[0,:]
# Out:
# a    0
# b    1
# c    2
# d    3
# Name: 0, dtype: int64

# %%
df.iloc[:, [0]]
# Out:
#     a
# 0   0
# 1   4
# 2   8
# 3  12
# 4  16

# %%
df.iloc[[0], :]
# Out:
#    a  b  c  d
# 0  0  1  2  3

# %%
df.iloc[[0,1], [-1, -2]]
# Out:
#    d  c
# 0  3  2
# 1  7  6

# %%
ser = pd.Series(["apple", "banana", "orange"], index=[0, 1, 1])
ser
# Out:
# 0     apple
# 1    banana
# 1    orange
# dtype: object

# %%
ser.loc[1]
# Out:
# 1    banana
# 1    orange
# dtype: object

# %%
ser = pd.Series([2, 2, 4], index=["dog", "cat", "human"], name="num_legs")
ser
# Out:
# dog      2
# cat      2
# human    4
# Name: num_legs, dtype: int64

# %%
ser.loc['dog']
# Out:
# 2

# %%
ser.loc[['dog','cat']]
# Out:
# dog    2
# cat    2
# Name: num_legs, dtype: int64

# %%
ser.loc[:'cat']
# Out:
# dog    2
# cat    2
# Name: num_legs, dtype: int64

# %%
values = ["Jack", "Jill", "Jayne"]
ser = pd.Series(values)
ser
# Out:
# 0     Jack
# 1     Jill
# 2    Jayne
# dtype: object

# %%
values[:2]
# Out:
# ['Jack', 'Jill']

# %%
ser.iloc[:2] # by index
# Out:
# 0    Jack
# 1    Jill
# dtype: object

# %%
ser.loc[:2] # by label
# Out:
# 0     Jack
# 1     Jill
# 2    Jayne
# dtype: object

# %%
repeats_2 = pd.Series(range(5), index=[0, 1, 2, 2, 0])
repeats_2.loc[:2]
# Out:
# 0    0
# 1    1
# 2    2
# 2    3
# dtype: int64

# %%
repeats_2.iloc[2]
# Out:
# 2

# %%
ser = pd.Series(range(4), index=["zzz", "xxx", "xxx", "yyy"])
ser.loc[:"xxx"]
# Out:
# zzz    0
# xxx    1
# xxx    2
# dtype: int64

# %%
df = pd.DataFrame([
 [24, 180, "blue"],
 [42, 166, "brown"],
 [22, 160, "green"],
], columns=["age", "height_cm", "eye_color"], index=["Jack", "Jill", "Jayne"])
df
# Out:
#        age  height_cm eye_color
# Jack    24        180      blue
# Jill    42        166     brown
# Jayne   22        160     green

# %%
df.loc['Jayne', 'eye_color']
# Out:
# 'green'

# %%
df.loc[:, 'age']
# Out:
# Jack     24
# Jill     42
# Jayne    22
# Name: age, dtype: int64

# %%
df.loc['Jack',:]
# Out:
# age            24
# height_cm     180
# eye_color    blue
# Name: Jack, dtype: object

# %%
df.loc[:,['age']]
# Out:
#        age
# Jack    24
# Jill    42
# Jayne   22

# %%
df.loc[['Jack'],:]
# Out:
#       age  height_cm eye_color
# Jack   24        180      blue

# %%
df.loc[['Jack', 'Jill'], ['age', 'eye_color']]
# Out:
#       age eye_color
# Jack   24      blue
# Jill   42     brown

# %% [markdown]
# ## Mixing Position-based and label-based selection

# %%
df = pd.DataFrame([
 [24, 180, "blue"],
 [42, 166, "brown"],
 [22, 160, "green"],
], columns=["age", "height_cm", "eye_color"])
df
# Out:
#    age  height_cm eye_color
# 0   24        180      blue
# 1   42        166     brown
# 2   22        160     green

# %%
col_idxer = df.columns.get_indexer(['age', 'eye_color'])
col_idxer
# Out:
# array([0, 2])

# %%
df.iloc[[0,1], col_idxer]
# Out:
#    age eye_color
# 0   24      blue
# 1   42     brown

# %%
df[['age', 'eye_color']].iloc[[0,1]]
# Out:
#    age eye_color
# 0   24      blue
# 1   42     brown

# %%
import timeit

def get_indexer_approach():
    col_idxer = df.columns.get_indexer(['age', 'eye_color'])
    df.iloc[[0,1], col_idxer]

timeit.timeit(get_indexer_approach, number=10_000)
# Out:
# 6.034293256000183

# %%
two_step_approach = lambda: df[['age', 'eye_color']].iloc[[0, 1]]
timeit.timeit(two_step_approach, number=10_000)
# Out:
# 6.549185565999778

# %% [markdown]
# ## DataFrame.filter

# %%
df = pd.DataFrame([
 [24, 180, "blue"],
 [42, 166, "brown"],
 [22, 160, "green"],
], columns=[
 "age",
 "height_cm",
 "eye_color"
], index=["Jack", "Jill", "Jayne"])
df
# Out:
#        age  height_cm eye_color
# Jack    24        180      blue
# Jill    42        166     brown
# Jayne   22        160     green

# %%
df.filter(['age', 'eye_color'])
# Out:
#        age eye_color
# Jack    24      blue
# Jill    42     brown
# Jayne   22     green

# %%
df.filter(like='_')
# Out:
#        height_cm eye_color
# Jack         180      blue
# Jill         166     brown
# Jayne        160     green

# %%
df.filter(regex=r"^Ja.*(?<!e)$", axis=0)
# Out:
#       age  height_cm eye_color
# Jack   24        180      blue

# %%
df = pd.DataFrame([
 [0, 1.0, "2"],
 [4, 8.0, "16"],
], columns=["int_col", "float_col", "string_col"])
df
# Out:
#    int_col  float_col string_col
# 0        0        1.0          2
# 1        4        8.0         16

# %%
df.select_dtypes('int')
# Out:
#    int_col
# 0        0
# 1        4

# %%
df.select_dtypes(include=['int', 'float'])
# Out:
#    int_col  float_col
# 0        0        1.0
# 1        4        8.0

# %%
df.select_dtypes(exclude=['int', 'float'])
# Out:
#   string_col
# 0          2
# 1         16

# %%
mask = [True, False, True]
ser = pd.Series(range(3))
ser
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
ser[mask]
# Out:
# 0    0
# 2    2
# dtype: int64

# %%
ser.loc[mask]
# Out:
# 0    0
# 2    2
# dtype: int64

# %%
df = pd.DataFrame(np.arange(6).reshape(3, -1))
df[mask]
# Out:
#    0  1
# 0  0  1
# 2  4  5

# %%
col_mask = [True, False]
df.loc[mask, col_mask]
# Out:
#    0
# 0  0
# 2  4

# %%
df = pd.DataFrame([
 [24, 180, "blue"],
 [42, 166, "brown"],
 [22, 160, "green"],
], columns=["age", "height_cm", "eye_color"], index=["Jack", "Jill", "Jayne"])
df
# Out:
#        age  height_cm eye_color
# Jack    24        180      blue
# Jill    42        166     brown
# Jayne   22        160     green

# %%
blue_eyes = df['eye_color'] == 'blue'
blue_eyes
# Out:
# Jack      True
# Jill     False
# Jayne    False
# Name: eye_color, dtype: bool

# %%
green_eyes = df['eye_color'] == 'green'
green_eyes
# Out:
# Jack     False
# Jill     False
# Jayne     True
# Name: eye_color, dtype: bool

# %%
mask = blue_eyes | green_eyes
mask
# Out:
# Jack      True
# Jill     False
# Jayne     True
# Name: eye_color, dtype: bool

# %%
df[mask]
# Out:
#        age  height_cm eye_color
# Jack    24        180      blue
# Jayne   22        160     green

# %%
age_lt_40 = df['age'] < 40
age_lt_40
# Out:
# Jack      True
# Jill     False
# Jayne     True
# Name: age, dtype: bool

# %%
height_gt_170 = df['height_cm'] > 170
height_gt_170
# Out:
# Jack      True
# Jill     False
# Jayne    False
# Name: height_cm, dtype: bool

# %%
df[age_lt_40 & height_gt_170]
# Out:
#       age  height_cm eye_color
# Jack   24        180      blue

# %%
df[~(age_lt_40 & height_gt_170)]
# Out:
#        age  height_cm eye_color
# Jill    42        166     brown
# Jayne   22        160     green

# %% [markdown]
# ## Selection with a MultiIndex - A single level

# %%
index = pd.MultiIndex.from_tuples([
    ("John", "Smith"),
    ("John", "Doe"),
    ("Jane", "Doe"),
    ("Stephen", "Smith"),
], names=["first_name", "last_name"])
ser = pd.Series(range(4), index=index)
ser
# Out:
# first_name  last_name
# John        Smith        0
#             Doe          1
# Jane        Doe          2
# Stephen     Smith        3
# dtype: int64

# %%
ser.loc['John']
# Out:
# last_name
# Smith    0
# Doe      1
# dtype: int64

# %%
ser.loc[['John']]
# Out:
# first_name  last_name
# John        Smith        0
#             Doe          1
# dtype: int64

# %%
index = pd.MultiIndex.from_tuples([
 ("John", "Smith"),
 ("John", "Doe"),
 ("Jane", "Doe"),
 ("Stephen", "Smith"),
], names=["first_name", "last_name"])
ser = pd.Series(range(4), index=index)
ser
# Out:
# first_name  last_name
# John        Smith        0
#             Doe          1
# Jane        Doe          2
# Stephen     Smith        3
# dtype: int64

# %%
ser.loc[('Jane', 'Doe')]
# Out:
# 2

# %%
ser.loc[(['Jane'], 'Doe')]
# Out:
# first_name  last_name
# Jane        Doe          2
# dtype: int64

# %%
ser.loc[[('John', 'Smith'), ('Jane', 'Doe')]]
# Out:
# first_name  last_name
# John        Smith        0
# Jane        Doe          2
# dtype: int64

# %%
ser.loc[(slice(None), 'Doe')]
# Out:
# first_name
# John    1
# Jane    2
# dtype: int64

# %%
ser.loc[(slice(None), ['Doe'])]
# Out:
# first_name  last_name
# John        Doe          1
# Jane        Doe          2
# dtype: int64

# %%
alist = list("abc")
alist[:]
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ==

# %%
alist[slice(None)]
# Out:
# ['a', 'b', 'c']

# %%
alist[slice(None)] == alist[:]
# Out:
# True

# %%
ser.loc[(slice(None), ['Doe'])]
# Out:
# first_name  last_name
# John        Doe          1
# Jane        Doe          2
# dtype: int64

# %%
ixsl = pd.IndexSlice
ser.loc[ixsl[:, ['Doe']]]
# Out:
# first_name  last_name
# John        Doe          1
# Jane        Doe          2
# dtype: int64

# %% [markdown]
# ## Selection with a MultiIndex - a DataFrame

# %%
row_index = pd.MultiIndex.from_tuples([
 ("John", "Smith"),
 ("John", "Doe"),
 ("Jane", "Doe"),
 ("Stephen", "Smith"),
], names=["first_name", "last_name"])
col_index = pd.MultiIndex.from_tuples([
 ("music", "favorite"),
 ("music", "last_seen_live"),
 ("art", "favorite"),
], names=["art_type", "category"])
df = pd.DataFrame([
 ["Swift", "Swift", "Matisse"],
 ["Mozart", "T. Swift", "Van Gogh"],
 ["Beatles", "Wonder", "Warhol"],
 ["Jackson", "Dylan", "Picasso"],
], index=row_index, columns=col_index)
df
# Out:
# art_type                music                      art
# category             favorite last_seen_live  favorite
# first_name last_name
# John       Smith        Swift          Swift   Matisse
#            Doe         Mozart       T. Swift  Van Gogh
# Jane       Doe        Beatles         Wonder    Warhol
# Stephen    Smith      Jackson          Dylan   Picasso

# %%
row_idxer = (slice(None), 'Smith')
col_idxer = (slice(None), 'favorite')
df.loc[row_idxer, col_idxer]
# Out:
# art_type                music      art
# category             favorite favorite
# first_name last_name
# John       Smith        Swift  Matisse
# Stephen    Smith      Jackson  Picasso
